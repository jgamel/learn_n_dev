# %% [markdown]
# <a href="https://colab.research.google.com/github/jgamel/learn_n_dev/blob/python_web_scrapping/web_scrapping_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scrapping Tutorials

# %% [markdown]
# This Notebook covers some of the most important libraries used in the space of web scraping used in the field of Data Science.
#
# Contents of the Tutorials
#
# * Web Scraping to Scrap Twitter
# * Web Scraping to Fetch News from Websites
# * Web Scraping to Fetch News from Newspapers and Articles
# * Web Scraping to Fetch Financial Data
# * Web Scraping to Scrap Reddit

# %% [markdown]
# Mount Drive for Libraries:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')

# %%
# importing basic libraries
import datetime as dt
import pandas as pd
import numpy as np

# importing libraries for scraping
from twitterscraper import query_tweets
from urllib.request import urlopen
from selenium import webdriver
from bs4 import BeautifulSoup
from newspaper import Article
import scrapy
import praw

# %% [markdown]
# ### Scraping Twitter

# %%
#Importing necessary files
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd

#Providing the range of days in which I want the data 
begin_date=dt.date(2020,4,1)
end_date=dt.date(2020,4,3)

#Providing limit to the fetched tweets and also specifying the language of the desired tweets
limit=1000
language='english'

#Extracting tweets for the Keyword “Covid-19”
tweets=query_tweets('Covid-19',limit=limit,
    begindate=begin_date,
    enddate=end_date,lang=language)

# %%
#Creating Dataframe for the extracted tweets
df=pd.DataFrame(t.__dict__ for t in tweets)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Scraping Reddit

# %%
def headline(company):
    headlines = set()
    reddit = praw.Reddit(client_id='F2uCF0oF0q46GA',
                     client_secret='5Vo58uJsQLDfoswrzOflyWWfNdQ',
                     user_agent='roshan220206')
    for submission in reddit.subreddit('google').new(limit=1000):
        headlines.add(submission.title)
       
    return headlines

# %%
headline('google')
# Out:
# It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
#
# It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
#
# It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
#
# It appears that you are using PRAW in an asynchronous environment.
# ...

# %% [markdown]
# ### Scraping Google News

# %%
def scrap(url):
    Client = urlopen(url)
    xml_page = Client.read()
    Client.close()
    soup_page = BeautifulSoup(xml_page, "xml")
    news_list = soup_page.findAll("item")

    # print news title, url and publish date
    
    for news in news_list:
        news_list = set()
        print(news.title.text), print(news.link.text), print(news.pubDate.text)

# %%
scrap("http://news.google.com/news/rss")
# Out:
# Ukraine-Russia Live News: U.S. Launches Task Force to Target Russian Oligarchs - Newsweek
# https://news.google.com/__i/rss/rd/articles/CBMia2h0dHBzOi8vd3d3Lm5ld3N3ZWVrLmNvbS91a3JhaW5lLWxpdmUtbmV3cy1ydXNzaWEtd2FyLXVwZGF0ZXMta3lpdi1raGFya2l2LWpvZS1iaWRlbi1wdXRpbi16ZWxlbnNreS0xNjgzOTk00gEA?oc=5
# Wed, 02 Mar 2022 18:39:50 GMT
# Manchin lays out a Dem bill he can back: Taxes, prescription drugs, climate cash - POLITICO
# https://news.google.com/__i/rss/rd/articles/CBMiUWh0dHBzOi8vd3d3LnBvbGl0aWNvLmNvbS9uZXdzLzIwMjIvMDMvMDIvam9lLW1hbmNoaW4tZGVtb2NyYXQtYmlsbC10YXhlcy0wMDAxMzI0NtIBAA?oc=5
# Wed, 02 Mar 2022 19:36:58 GMT
# Justice Department launches special unit to enforce Russia sanctions - NBC News
# https://news.google.com/__i/rss/rd/articles/CBMif2h0dHBzOi8vd3d3Lm5iY25ld3MuY29tL3BvbGl0aWNzL2p1c3RpY2UtZGVwYXJ0bWVudC9qdXN0aWNlLWRlcGFydG1lbnQtbGF1bmNoZXMtc3BlY2lhbC11bml0LWVuZm9yY2UtcnVzc2lhLXNhbmN0aW9ucy1yY25hMTgzMjLSAQA?oc=5
# Wed, 02 Mar 2022 17:04:53 GMT
# ...

# %% [markdown]
# ### Scraping Newspapers/Articles

# %%
#A new article from TOI 
url = "https://timesofindia.indiatimes.com/"

# %%
#For different language newspaper refer above table 
toi_article = Article(url, language="en") # en for English

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#To download the article 
toi_article.download() 
  
#To parse the article 
toi_article.parse() 
  
#To perform natural language processing ie..nlp 
toi_article.nlp()

# %%
#To extract title 
print("Article's Title:") 
print(toi_article.title) 
print("n") 
  
#To extract text 
print("Article's Text:") 
print(toi_article.text) 
print("n") 
  
#To extract summary 
print("Article's Summary:") 
print(toi_article.summary) 
print("n") 
  
#To extract keywords 
print("Article's Keywords:") 
print(toi_article.keywords)
# Out:
# Article's Title:
# News: US News, Top News in India, US election news, Business news, Sports & International News
# n
# Article's Text:
# Jhund
#
# To sum up, this one’s a dramatic sports film, which may not have thrilling moments around every corner for you but the point it tries to drive home will definitely kick your insides hard.
# n
# Article's Summary:
# JhundTo sum up, this one’s a dramatic sports film, which may not have thrilling moments around every corner for you but the point it tries to drive home will definitely kick your insides hard.
# n
# Article's Keywords:
# ['international', 'point', 'kick', 'india', 'tries', 'jhundto', 'insides', 'sum', 'hard', 'thrilling', 'business', 'election', 'ones', 'moments']
