# %% [markdown]
# <a href="https://colab.research.google.com/github/jgamel/learn_n_dev/blob/python_web_scrapping/finnews_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install finnews
# !pip install fin-news
# Out:
# Collecting fin-news
#   Downloading fin_news-0.1.2-py3-none-any.whl (19 kB)
# Collecting fake-useragent==0.1.11
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting requests>=2.24.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.4 MB/s
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->fin-news) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->fin-news) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->fin-news) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->fin-news) (2.10)
# Building wheels for collected packages: fake-useragent
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=5ff7b4eba54cd98794b6ea30bbe9a4a9a920b881ae06c146fbb299b43883bf86
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# Successfully built fake-useragent
# Installing collected packages: requests, fake-useragent, fin-news
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed fake-useragent-0.1.11 fin-news-0.1.2 requests-2.27.1

# %%
from pprint import pprint
from finnews.client import News

# Create a new instance of the News Client.
news_client = News()

# Grab the CNBC News Client.
cnbc_news_client = news_client.cnbc

# Grab the top news.
cbnc_top_news = cnbc_news_client.news_feed(topic='top_news')

# Print it.
pprint(cbnc_top_news)
# Out:
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/fake_useragent/utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "/usr/local/lib/python3.7/dist-packages/fake_useragent/utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range
# [{'description': "Stocks reversed some of Wednesday's rally.",
#   'guid': '107056067',
#   'id': '107056067',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/04/stock-market-futures-open-to-close-news.html',
#   'pubDate': 'Thu, 05 May 2022 14:51:02 GMT',
#   'sponsored': 'false',
#   'title': 'Stocks extend losses, with Dow dropping 800 points, as post-Fed '
#            'rally evaporates',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Worker productivity fell to start 2022 at its fastest pace '
#                  'in nearly 75 years while labor costs soared.',
#   'guid': '107056489',
#   'id': '107056489',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/labor-productivity-fell-7point5percent-in-the-first-quarter-the-fastest-rate-since-1947.html',
#   'pubDate': 'Thu, 05 May 2022 13:41:38 GMT',
#   'sponsored': 'false',
#   'title': 'Worker output fell 7.5% in the first quarter, the biggest decline '
#            'since 1947',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Elon Musk is expected to serve as a temporary Twitter CEO '
#                  'for a few months after he completes his takeover of the '
#                  "company, sources told CNBC's David Faber.",
#   'guid': '107056533',
#   'id': '107056533',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/elon-musk-expected-to-serve-as-temporary-twitter-ceo-after-deal-closes.html',
#   'pubDate': 'Thu, 05 May 2022 14:06:40 GMT',
#   'sponsored': 'false',
#   'title': 'Elon Musk expected to serve as temporary Twitter CEO after deal '
#            'closes',
#   'type': 'cnbcnewsstory'},
#  {'description': "The changes would tailor the Community Reinvestment Act's "
#                  'approach to making sure banks are not engaging in '
#                  '"redlining."',
#   'guid': '107056539',
#   'id': '107056539',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/feds-propose-first-major-revamp-to-fair-housing-rules-since-1995.html',
#   'pubDate': 'Thu, 05 May 2022 13:53:03 GMT',
#   'sponsored': 'false',
#   'title': 'Feds propose first major revamp to fair housing rules since 1995',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Oracle co-founder Larry Ellison, venture capital firm '
#                  'Sequoia and crypto exchange Binance are among the investors '
#                  "that plan to support Elon Musk's Twitter bid.",
#   'guid': '107056459',
#   'id': '107056459',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/larry-ellison-sequoia-and-binance-to-help-musk-to-pay-for-twitter.html',
#   'pubDate': 'Thu, 05 May 2022 14:52:32 GMT',
#   'sponsored': 'false',
#   'title': 'Elon Musk got another $7 billion from friends and investors to buy '
#            'Twitter',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Shopify announced it would buy Deliverr, which provides '
#                  'fulfillment services for online merchants, for $2.1 billion, '
#                  'the largest acquisition in its history.',
#   'guid': '107056506',
#   'id': '107056506',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/shopify-sinks-after-earnings-miss-2point1-billion-purchase-of-deliverr.html',
#   'pubDate': 'Thu, 05 May 2022 14:29:16 GMT',
#   'sponsored': 'false',
#   'title': 'Shopify stock down 17% after earnings miss, $2.1 billion '
#            'acquisition of logistics start-up',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Stock futures were down in early morning trading after a '
#                  'major Fed-led rally on Wednesday.',
#   'guid': '107056488',
#   'id': '107056488',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/cramer-is-watching-thursday-fed-hike-rally-musk-gets-help-for-twitter-bid.html',
#   'pubDate': 'Thu, 05 May 2022 13:15:26 GMT',
#   'sponsored': 'false',
#   'title': 'What Cramer is watching Thursday — Fed hike rally, Musk gets help '
#            'for Twitter bid',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Elon Musk and Cathie Wood took aim at index funds, arguing '
#                  'that passive investments have controlled too big a '
#                  'percentage of the stock market.',
#   'guid': '107056479',
#   'id': '107056479',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/elon-musk-and-cathie-wood-knock-passive-index-investing-saying-its-gone-too-far.html',
#   'pubDate': 'Thu, 05 May 2022 14:49:54 GMT',
#   'sponsored': 'false',
#   'title': 'Elon Musk and Cathie Wood knock passive index investing, saying '
#            'it’s gone too far',
#   'type': 'cnbcnewsstory'},
#  {'description': "The seizure of Suleiman Kerimov's superyacht is part of a "
#                  'broader effort to take the assets of sanctioned oligarchs as '
#                  'Russia invades Ukraine.',
#   'guid': '107056513',
#   'id': '107056513',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/fiji-seizes-superyacht-belonging-to-russian-oligarch-suleiman-kerimov.html',
#   'pubDate': 'Thu, 05 May 2022 14:42:08 GMT',
#   'sponsored': 'false',
#   'title': 'Fiji seizes $300 million superyacht belonging to Russian oligarch '
#            'Suleiman Kerimov',
#   'type': 'cnbcnewsstory'},
#  {'description': "The cost of money is rising for borrowers. So why aren't "
#                  'savers being rewarded?',
#   'guid': '107056469',
#   'id': '107056469',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/despite-the-feds-big-rate-hike-most-banks-wont-pay-much-in-interest.html',
#   'pubDate': 'Thu, 05 May 2022 14:07:50 GMT',
#   'sponsored': 'false',
#   'title': 'Despite the Fed’s big rate boost, most banks will still pay paltry '
#            'interest rates',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Americans are more likely to fear the metaverse than be '
#                  'excited about it, according to a recent Axios-Momentive '
#                  "survey. Even more likely: You don't know what to think, or "
#                  "you don't care.",
#   'guid': '107056002',
#   'id': '107056002',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/more-americans-are-scared-of-the-metaverse-than-excited-poll.html',
#   'pubDate': 'Thu, 05 May 2022 14:49:52 GMT',
#   'sponsored': 'false',
#   'title': 'Nearly a third of U.S. adults are more ‘scared’ of the metaverse '
#            "than 'excited'",
#   'type': 'cnbcnewsstory'},
#  {'description': "Changpeng Zhao, Binance's CEO, is a big believer in the "
#                  "crypto world's vision of a new kind of internet, known as "
#                  '"Web3."',
#   'guid': '107056408',
#   'id': '107056408',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/binance-backing-for-elon-musks-twitter-bid-boosts-web3-vision.html',
#   'pubDate': 'Thu, 05 May 2022 14:56:24 GMT',
#   'sponsored': 'false',
#   'title': "Binance is backing Elon Musk's Twitter bid, boosting crypto "
#            "believers' vision of a 'decentralized' web",
#   'type': 'cnbcnewsstory'},
#  {'description': "Baron's firm committed $100 million in equity to support "
#                  "Musk's takeover plans, a new filing revealed Thursday.",
#   'guid': '107056535',
#   'id': '107056535',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/tesla-bull-ron-baron-says-musk-got-a-good-deal-on-twitter.html',
#   'pubDate': 'Thu, 05 May 2022 13:59:29 GMT',
#   'sponsored': 'false',
#   'title': "Tesla bull Ron Baron says Musk got an 'incredibly cheap' deal on "
#            'Twitter',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Health Commissioner Ashwin Vasan said the city could '
#                  'reinstate mask mandates and vaccine checks if '
#                  'hospitalizations overwhelm the health system.',
#   'guid': '107055466',
#   'id': '107055466',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/covid-new-york-city-could-bring-back-mask-mandate-vaccine-checks.html',
#   'pubDate': 'Thu, 05 May 2022 12:00:01 GMT',
#   'sponsored': 'false',
#   'title': 'New York City could bring back Covid mask mandate, vaccine checks '
#            'if hospitals come under pressure',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Nikola reported a Q1 loss per share that was narrower than '
#                  'Wall Street expected and confirmed that its fuel cell truck '
#                  'is on track for a 2023 launch.',
#   'guid': '107056053',
#   'id': '107056053',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/nikola-nkla-earnings-q1-2022.html',
#   'pubDate': 'Thu, 05 May 2022 14:12:53 GMT',
#   'sponsored': 'false',
#   'title': 'Nikola stock jumps as EV truck maker reports start to production '
#            'and surprise Q1 revenue',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Interns on Wall Street are seeing a significant increase in '
#                  'compensation this year,',
#   'guid': '107052852',
#   'id': '107052852',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/wall-street-interns-are-earning-37percent-more-this-year-new-research-shows.html',
#   'pubDate': 'Thu, 05 May 2022 14:52:50 GMT',
#   'sponsored': 'false',
#   'title': 'Wall Street interns are making 30% more this year—some making over '
#            '$10,000 a month',
#   'type': 'cnbcnewsstory'},
#  {'description': "Amid the shrinking, toxic Salton Sea, there's enough lithium "
#                  "to meet the United States' entire projected demand and fuel "
#                  'the electric-vehicle revolution.',
#   'guid': '107053405',
#   'id': '107053405',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/04/the-salton-sea-could-produce-the-worlds-greenest-lithium.html',
#   'pubDate': 'Wed, 04 May 2022 19:51:40 GMT',
#   'sponsored': 'false',
#   'title': "The Salton Sea could produce the world's greenest lithium, if new "
#            'extraction technologies work',
#   'type': 'cnbcnewsstory'},
#  {'description': 'With the Federal Reserve increasing a key interest rate, '
#                  'borrowing costs are poised to head higher on a variety of '
#                  'consumer loans, including those for autos.',
#   'guid': '107055853',
#   'id': '107055853',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/rising-interest-rates-mean-higher-borrowing-costs-to-buy-a-car.html',
#   'pubDate': 'Thu, 05 May 2022 13:46:34 GMT',
#   'sponsored': 'false',
#   'title': 'Rising interest rates mean higher loan costs when you go to buy a '
#            'car. Monthly payments already average $650',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Wayfair co-founder and Chief Executive Officer Niraj Shah '
#                  'said, despite sliding sales, consumer health remains '
#                  '"relatively strong."',
#   'guid': '107056470',
#   'id': '107056470',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/wayfair-w-reports-q1-2022-losses.html',
#   'pubDate': 'Thu, 05 May 2022 13:49:07 GMT',
#   'sponsored': 'false',
#   'title': 'Wayfair loses customers and money in a messy quarter, announces '
#            'its CFO will retire',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Drawing on decades of research, social psychologist and '
#                  'communications expert Tessa West breaks down the seven types '
#                  "of jerks you're most likely to encounter at work. From "
#                  "gaslighters to credit stealers, here's how to identify — and "
#                  'work with — each one.',
#   'guid': '107046309',
#   'id': '107046309',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/psychologist-says-there-are-7-types-of-toxic-jerks-use-this-chart-to-see-which-one-you-work-with.html',
#   'pubDate': 'Thu, 05 May 2022 14:48:03 GMT',
#   'sponsored': 'false',
#   'title': "There are 7 types of 'office jerks,' says psychologist: This chart "
#            'tells you which one you work with',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Eight in ten small business owners across the U.S. tell CNBC '
#                  'that they expect the economy to enter a recession this year.',
#   'guid': '107056030',
#   'id': '107056030',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/main-street-is-more-sure-than-wall-street-a-recession-is-coming.html',
#   'pubDate': 'Thu, 05 May 2022 14:42:18 GMT',
#   'sponsored': 'false',
#   'title': 'Main Street is convinced that a recession will hit the U.S. '
#            'economy this year',
#   'type': 'cnbcnewsstory'},
#  {'description': 'The Bank of England on Thursday raised interest rates to '
#                  'their highest level in 13 years in a bid to tackle soaring '
#                  'inflation.',
#   'guid': '107056414',
#   'id': '107056414',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/bank-of-england-hikes-interest-rates-in-bid-to-fight-soaring-inflation.html',
#   'pubDate': 'Thu, 05 May 2022 15:02:45 GMT',
#   'sponsored': 'false',
#   'title': 'Bank of England hikes interest rates to 13-year high, sees '
#            'inflation hitting 10%',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Itaipu commenced electricity production in 1984.',
#   'guid': '107056386',
#   'id': '107056386',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/ge-signs-contract-to-upgrade-vast-hydropower-facility-in-south-america.html',
#   'pubDate': 'Thu, 05 May 2022 09:05:37 GMT',
#   'sponsored': 'false',
#   'title': 'World’s second-largest hydropower plant set for 14-year upgrade '
#            'after deal with GE',
#   'type': 'cnbcnewsstory'},
#  {'description': 'The studio, called Jackalope Games, is based in Austin, TX '
#                  'and will be tasked with creating new PC and console games '
#                  'for NetEase.',
#   'guid': '107056429',
#   'id': '107056429',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/chinese-tech-giant-netease-launches-first-gaming-studio-in-us.html',
#   'pubDate': 'Thu, 05 May 2022 12:47:38 GMT',
#   'sponsored': 'false',
#   'title': 'Chinese tech giant NetEase launches first gaming studio in U.S. in '
#            'international push',
#   'type': 'cnbcnewsstory'},
#  {'description': 'In football locker rooms, ex-Super Bowl champion Ryan Mundy '
#                  'saw mental health issues often get ignored. So, he started a '
#                  'company to support Black mental health.',
#   'guid': '107055457',
#   'id': '107055457',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/this-ex-super-bowl-champ-has-a-mental-health-app-for-black-millennials.html',
#   'pubDate': 'Thu, 05 May 2022 13:14:11 GMT',
#   'sponsored': 'false',
#   'title': 'This ex-Super Bowl champion wants to help make mental health more '
#            'affordable for Black millennials',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Meslow will also be leaving his position as a member of Bath '
#                  "& Body Works' board.",
#   'guid': '107056458',
#   'id': '107056458',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/bath-body-works-ceo-andrew-meslow-to-step-down-due-to-health-reasons.html',
#   'pubDate': 'Thu, 05 May 2022 12:53:36 GMT',
#   'sponsored': 'false',
#   'title': 'Bath & Body Works CEO Andrew Meslow to step down due to health '
#            'reasons',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Fanatics, which has an estimated valuation of $27 billion, '
#                  'wants to transform into a $100 billion company that offers '
#                  'online sports gambling.',
#   'guid': '107056178',
#   'id': '107056178',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/fanatics-adds-softbank-executive-ex-airbnb-marketing-chief-to-board.html',
#   'pubDate': 'Thu, 05 May 2022 12:00:01 GMT',
#   'sponsored': 'false',
#   'title': 'Fanatics adds SoftBank executive, former Airbnb marketing chief to '
#            'board of directors',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Bank of England policymakers warned that GDP growth is '
#                  'expected to slow sharply and inflation could peak at 10% '
#                  'this year.',
#   'guid': '107056493',
#   'id': '107056493',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/british-pound-sinks-against-dollar-set-for-worst-daily-drop-since-march-2020.html',
#   'pubDate': 'Thu, 05 May 2022 14:18:46 GMT',
#   'sponsored': 'false',
#   'title': 'British pound plummets as Bank of England warns of recession risk',
#   'type': 'cnbcnewsstory'},
#  {'description': "Shell's bumper earnings echo profits seen across the oil and "
#                  'gas industry, even as many energy majors incur costly '
#                  'write-downs from exiting Russia.',
#   'guid': '107055784',
#   'id': '107055784',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/shell-earnings-q1-2022.html',
#   'pubDate': 'Thu, 05 May 2022 08:24:24 GMT',
#   'sponsored': 'false',
#   'title': 'Oil giant Shell reports highest quarterly profit since 2008 on '
#            'soaring commodity prices',
#   'type': 'cnbcnewsstory'},
#  {'description': 'Oil producer group OPEC+ on Thursday agreed to rubber-stamp '
#                  'another small production increase for June.',
#   'guid': '107056384',
#   'id': '107056384',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/05/05/opec-meeting-oil-prices-climb-as-group-asssess-eu-russian-ban.html',
#   'pubDate': 'Thu, 05 May 2022 12:15:40 GMT',
#   'sponsored': 'false',
#   'title': 'OPEC+ agrees to another modest production increase after EU '
#            'outlines Russian oil ban',
#   'type': 'cnbcnewsstory'}]
