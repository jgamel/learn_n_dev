# %% [markdown]
# <a href="https://colab.research.google.com/github/jgamel/learn_n_dev/blob/python_web_scrapping/finnews_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')

# %%
from pprint import pprint
from finnews.client import News

# Create a new instance of the News Client.
news_client = News()

# Grab the CNBC News Client.
cnbc_news_client = news_client.cnbc

# Grab the top news.
cbnc_top_news = cnbc_news_client.news_feed(topic='top_news')

# Print it.
pprint(cbnc_top_news)
# Out:
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "/content/gdrive/My Drive/Colab Notebooks/fake_useragent/utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "/content/gdrive/My Drive/Colab Notebooks/fake_useragent/utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range
# [{'description': "Some retailers, including Victoria's Secret, are warning "
#                  'about business impacts from the Ukraine crisis. Others, like '
#                  'Nike, have suspended operations in Russia.',
#   'guid': '107016788',
#   'id': '107016788',
#   'item': '',
#   'link': 'https://www.cnbc.com/2022/03/03/ukraine-news-retailers-start-warn-of-business-impact-from-russian-invasion.html',
#   'pubDate': 'Thu, 03 Mar 2022 18:43:15 GMT',
# ...
